# %%
import pandas as pd
import os

from utils.downloader_csv import main as downloader_csv
from utils.read_csv_file import main as read_csv_file

from utils.downloader_xlsx import main as downloader_xlsx
from utils.read_xlsx_file import main as read_xlsx_file
from utils.shorten_csv import processBroker

# %%
def csvCompiler(counter):
    downloader_csv(counter)

    files = os.listdir('./data/csv')
    files.sort()
    files = files[-counter:]
    

    df = pd.DataFrame()
    for file in files:
        data = read_csv_file(file)
        df = pd.concat([df, data])
        
    masterFile = pd.read_csv('./data/GFI_csvs.csv',parse_dates=['date','period'])
    df = pd.concat([masterFile,df])
    df = df.drop_duplicates(subset=['periodType', 'date', 'instrument', 'period'], keep='last') 
    df.to_csv('./data/GFI_csvs.csv', index=False)
    processBroker(df,'./data/', 'GFI_csvs', './data/master/', 'BROKER/MASTER')


    return df    

def xlsxDownloader(counter):
    downloader_xlsx(counter)

    files = os.listdir('./data/xlsx')
    files.sort()
    files = files[-counter:]

    df = pd.DataFrame()
    for file in files:
        data = read_xlsx_file(file)
        df = pd.concat([df, data])
        
    masterFile = pd.read_csv('./data/GFI_xlsx.csv',parse_dates=['date','period'])
    df = pd.concat([masterFile,df])
    df = df.drop_duplicates(subset=['periodType', 'date', 'instrument', 'period'], keep='last') 
    df.to_csv('./data/GFI_xlsx.csv', index=False)
    processBroker(df,'./data/', 'GFI_xlsx', './data/master/', 'BROKER/MASTER')

    return df

# %%
counter = 5
    
csvCompiler(counter)
xlsxDownloader(counter)
# Out:
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-10.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-11.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-12.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\orrection).csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-13.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-14.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-17.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-18.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-19.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-20.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-21.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-24.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-25.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-26.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-27.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-02-28.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-03-03.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/csv\2025-03-04.csv
# ALI: https://pcia-crude.oss-us-east-1.aliyuncs.com/BROKER/MASTER/GFI_csvs.csv
# ALI: https://pcia-crude.oss-us-east-1.aliyuncs.com/BROKER/MASTER/GFI_csvs_60.csv
# ALI: https://pcia-crude.oss-us-east-1.aliyuncs.com/BROKER/MASTER/GFI_csvs_30.csv
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-10.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-11.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-12.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\orrection).xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-13.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-14.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-17.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-18.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-19.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-20.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-21.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-24.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-25.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-26.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-27.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-02-28.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-03-03.xlsx
# Saving file: c:\Users\crudeservice\Documents\lambda\broker_gfi\./data/xlsx\2025-03-04.xlsx
# ALI: https://pcia-crude.oss-us-east-1.aliyuncs.com/BROKER/MASTER/GFI_xlsx.csv
# ALI: https://pcia-crude.oss-us-east-1.aliyuncs.com/BROKER/MASTER/GFI_xlsx_60.csv
# ALI: https://pcia-crude.oss-us-east-1.aliyuncs.com/BROKER/MASTER/GFI_xlsx_30.csv
#     source periodType       date instrument     period  uom      value
# 0      GFI    MONTHLY 2023-06-19        TD3 2023-06-01  WSC   71.00000
# 1      GFI    MONTHLY 2023-06-19       TD20 2023-06-01  WSC  117.00000
# 2      GFI    MONTHLY 2023-06-19        TD7 2023-06-01  WSC  140.00000
# 3      GFI    MONTHLY 2023-06-19        TD8 2023-06-01  WSC  180.00000
# 4      GFI    MONTHLY 2023-06-19       TD25 2023-06-01  WSC  181.50000
# ..     ...        ...        ...        ...        ...  ...        ...
# 128    GFI     YEARLY 2025-03-04        TD7 2028-01-01  PMT    9.70000
# 129    GFI     YEARLY 2025-03-04        TD8 2028-01-01  PMT   20.30000
# 130    GFI     YEARLY 2025-03-04       TD25 2028-01-01  PMT   22.46424
# 131    GFI     YEARLY 2025-03-04       TD22 2028-01-01  LSM    7.15000
# 132    GFI     YEARLY 2025-03-04       TD19 2028-01-01  PMT   13.55000
#
# [55976 rows x 7 columns]
